# %%
from google.colab import drive 
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from PIL import Image
path = '/content/drive/My Drive/Colab Notebooks/images/'

# %%
img =Image.open(path+'foto6.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=419x396 at 0x7FB77B457E48>

# %%
img.getpixel((100,100))
# Out:
# (76, 32, 47)

# %%
img_grey = img.convert('L')
img_grey
# Out:
# <PIL.Image.Image image mode=L size=419x396 at 0x7FB77B457D30>

# %%
img_grey.save(path+'img_grey.jpeg')

# %%
img_grey1 = img.convert('1')
img_grey1
# Out:
# <PIL.Image.Image image mode=1 size=419x396 at 0x7FB77B45F320>

# %%
img_grey1.save =(path+'img_grey1.tiff')

# %%
img_greyL = img.convert('L')
img_greyL
# Out:
# <PIL.Image.Image image mode=L size=419x396 at 0x7FB77B457828>

# %%
img_greyL.save(path+'img_greyL.tiff')

# %%
img_greyP = img.convert('P')
img_greyP
# Out:
# <PIL.Image.Image image mode=P size=419x396 at 0x7FB77B45FC50>

# %%
img_greyP.save(path+'img_greyP.tiff
')
